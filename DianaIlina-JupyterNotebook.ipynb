# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Diana Ilina** <br>
# In the future Senior Data Scientist

# %% [markdown]
# *I am interested in data science because for me, data science was a way to become a detective. For every new case, you have to go into a new field to try to understand how it works, to massage the data until you understand them, to try to acquire all the knowledge of the field without being a specialist. And because I am very curious about very different techniques in science, for me, it is exactly what I wanted.*

# %% [markdown]
# ### The program displays the normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy. stats import norm

#x-axis ranges from -3 and 3 with .001 steps
x = np.arange (-3, 3, 0.001)

#plot normal distribution with mean 0 and standard deviation 1
plt.plot (x, norm. pdf (x, 0, 1))

# %% [markdown]
# ----------------------------
#
# * bulleted list element 1
# * bulleted list element 2
#     + element of the second level of the bulleted list 1
#     + element of the second level of the bulleted list 2
#         - element of the third level of the bulleted list 1
#         - element of the third level of the bulleted list 2
#         - element of the third level of the bulleted list 3
#
# 1. numbered list 1
# 2. numbered list 2
# 3. numbered list 3
#
#   Name     |   Surname   |   Date of Birth
# -----------|-------------|:----------------:
#    Dean    | Winchester  | January 24, 1979
#    Sam     | Winchester  |    May 2, 1983
#
#
# [Hi this is my GitHub](https://github.com/diana-ilina "My GitHub")
#
# ![Jupyter logo](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTusrGtCF5cVIZ54R8B8JswjAOM8XYyNl553izj3v0fLFSItt46yWSlEX0TD8AD7AY9eh4&usqp=CAU "Jupyter logo")
#
# Some basic Git commands are:
# ```
# git status
# git add
# git commit
# ```
#
# ~~This was mistaken text~~
#
#
#
# >Without data you’re just another person with an opinion
